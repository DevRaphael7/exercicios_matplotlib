# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
tabela = pd.read_csv(r"Tabelas\attendance.csv", sep=';', encoding = "ISO-8859-1")
tabela
# Out:
#        attendance  total  male  female  poorest_20perc  richest_20perc  \
# 0           Yemen      3     3       3               0               8
# 1     Afghanistan      1     1       1               0               4
# 2         Somalia      2     2       2               1               6
# 3            Chad      3     3       3               1              11
# 4   Côte d'Ivoire      5     5       5               1              15
# ..            ...    ...   ...     ...             ...             ...
# 61           Peru     77    76      79              70              90
# 62        Belarus     88    86      89              75              91
# 63       Thailand     85    84      85              86              84
# 64        Jamaica     92    92      91              88             100
# 65       Barbados     90    88      91              90              97
#
#             source
# 0          #######
# 1   MICS 2011-2012
# 2          #######
# 3          #######
# ...

# %%
tabela.shape
# Out:
# (66, 7)

# %%
tabela['attendance'].unique()
# Out:
# array(['Yemen', 'Afghanistan', 'Somalia', 'Chad', "Côte d'Ivoire",
#        'Democratic Republic of the Congo', 'Iraq', 'Mali',
#        'Central African Republic ', 'South Sudan',
#        'Bosnia and Herzegovina', 'Benin', 'Cameroon', 'Rwanda', 'Bhutan',
#        'Guinea-Bissau', 'Syrian Arab Republic', 'Burundi', 'Sierra Leone',
#        "Lao People's Democratic Republic", 'Morocco', 'Cambodia',
#        'Montenegro', 'Sudan', 'Algeria', 'Costa Rica', 'Serbia',
#        'Nigeria', 'Jordan', 'Myanmar', 'Senegal', 'Bangladesh',
#        'Kyrgyzstan', 'Gambia', 'Honduras', 'Tunisia', 'Togo',
#        'Dominican Republic', 'Suriname', 'Zimbabwe', 'Turkmenistan',
#        'El Salvador', 'State of Palestine', 'Sao Tome and Principe',
#        'Albania', 'Malawi', 'Panama', 'Swaziland', 'Belize', 'Ukraine',
#        'Egypt', 'Mongolia', 'Nepal', 'Ghana', 'Guyana', 'Kazakhstan',
#        'Argentina', 'Republic of Moldova', 'Viet Nam', 'Mexico',
# ...

# %% [markdown]
# # Número de homens e mulheres por país

# %%
plt.figure(figsize=(18, 14))
table = tabela[['attendance', 'total']]
plt.bar(table['attendance'], table['total'])
plt.xticks(rotation=60)
plt.show()

# %%
print(tabela['male'].sum(), tabela['female'].sum())
# Out:
# 2211 2289
