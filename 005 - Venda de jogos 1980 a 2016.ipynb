# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
tabela = pd.read_csv(r'Tabelas\vgsales.csv', sep=',')
tabela.head(10)
# Out:
#    Rank                       Name Platform    Year         Genre Publisher  \
# 0     1                 Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2          Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3             Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4          Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5   Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
# 5     6                     Tetris       GB  1989.0        Puzzle  Nintendo
# 6     7      New Super Mario Bros.       DS  2006.0      Platform  Nintendo
# 7     8                   Wii Play      Wii  2006.0          Misc  Nintendo
# 8     9  New Super Mario Bros. Wii      Wii  2009.0      Platform  Nintendo
# 9    10                  Duck Hunt      NES  1984.0       Shooter  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# ...

# %% [markdown]
# # Quais são os jogos mais vendidos (Variável Global_Sales) ?
#
# - 10 jogos mais vendidos
# - 10 jogos menos vendidos do Dataset
# - Plotando Gráfico dos jogos mais vendidos( dos 10 e 30 mais vendidos)

# %%
jogosMaisVendidos = pd.DataFrame(tabela['Name'])
jogosMaisVendidos['Vendas_globais'] = tabela['Global_Sales']
jogosMaisVendidos.sort_values(by=['Vendas_globais'], ascending = False).head(10)
# Out:
#                         Name  Vendas_globais
# 0                 Wii Sports           82.74
# 1          Super Mario Bros.           40.24
# 2             Mario Kart Wii           35.82
# 3          Wii Sports Resort           33.00
# 4   Pokemon Red/Pokemon Blue           31.37
# 5                     Tetris           30.26
# 6      New Super Mario Bros.           30.01
# 7                   Wii Play           29.02
# 8  New Super Mario Bros. Wii           28.62
# 9                  Duck Hunt           28.31

# %%
jogosMaisVendidos.sort_values(by=['Vendas_globais'], ascending = True).head(10)
# Out:
#                                                   Name  Vendas_globais
# 16597                                 Spirits & Spells            0.01
# 16188                                 Toro to Morimori            0.01
# 16187                                   Jewel Quest II            0.01
# 16186                                      BattleForge            0.01
# 16185           Tantei Jinguuji Saburo: Hai to Diamond            0.01
# 16184  Fatal Fury: Battle Archives Volume 2 (JP sales)            0.01
# 16183                      Sakura-Sou no Pet na Kanojo            0.01
# 16182                                  Princess Arthur            0.01
# 16181                             Resistance Dual Pack            0.01
# 16180                        Rozen Maiden: Gebetgarten            0.01

# %%
x = jogosMaisVendidos.sort_values(by=['Vendas_globais'], ascending = False).head(10)
plt.barh(x['Name'], x['Vendas_globais'])
plt.show()

# %% [markdown]
# Os 30 jogos mais vendidos

# %%
x = jogosMaisVendidos.sort_values(by=['Vendas_globais'], ascending = False).head(30)
plt.figure(figsize=(14, 10))
plt.barh(x['Name'], x['Vendas_globais'])
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# O jogo Wii Sports é o jogo mais vendido na variável Vendas_globais do dataset

# %% [markdown]
# # Vendas pela variável NA_Sales
#
# - Mostrar a tabela com as variáveis Name e NA_Sales
# - Maiores número de vendas da variável NA_Sales
# - Protando gráficos

# %%
vendas_na = pd.DataFrame(tabela[['Name', 'NA_Sales']])
vendas_na
# Out:
#                                                    Name  NA_Sales
# 0                                            Wii Sports     41.49
# 1                                     Super Mario Bros.     29.08
# 2                                        Mario Kart Wii     15.85
# 3                                     Wii Sports Resort     15.75
# 4                              Pokemon Red/Pokemon Blue     11.27
# ...                                                 ...       ...
# 16593                Woody Woodpecker in Crazy Castle 5      0.01
# 16594                     Men in Black II: Alien Escape      0.01
# 16595  SCORE International Baja 1000: The Official Game      0.00
# 16596                                        Know How 2      0.00
# 16597                                  Spirits & Spells      0.01
#
# [16598 rows x 2 columns]

# %%
tabela[['Name','NA_Sales']].sort_values(by='NA_Sales',ascending = False).head(10)
# Out:
#                          Name  NA_Sales
# 0                  Wii Sports     41.49
# 1           Super Mario Bros.     29.08
# 9                   Duck Hunt     26.93
# 5                      Tetris     23.20
# 2              Mario Kart Wii     15.85
# 3           Wii Sports Resort     15.75
# 15         Kinect Adventures!     14.97
# 8   New Super Mario Bros. Wii     14.59
# 7                    Wii Play     14.03
# 18          Super Mario World     12.78

# %%
x = vendas_na.sort_values(by='NA_Sales', ascending=False).head(15)
plt.figure(figsize=(10, 6))
plt.title("Número das 15 maiores vendas da variável NA_Sales\n", fontsize=20)
plt.xlabel("\nNúmero de vendas", fontsize=10)
plt.ylabel("Games\n", fontsize=10)
plt.barh(x['Name'], x['NA_Sales'])
# Out:
# <BarContainer object of 15 artists>

# %%
x = x.sort_values( by='NA_Sales', ascending=True)
plt.plot(x['Name'], x['NA_Sales'], 'o-')
plt.xlabel("\nJogos")
plt.ylabel("Número de vendas\n")
plt.grid(True)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Os jogos mais vendidos do Japão
#
# - Tabela com as variáveis Name e JP_Sales
# - Os 15 jogos mais vendidos no Japão
# - Plotando Gráficos

# %%
tabela[['Name', 'JP_Sales']]
# Out:
#                                                    Name  JP_Sales
# 0                                            Wii Sports      3.77
# 1                                     Super Mario Bros.      6.81
# 2                                        Mario Kart Wii      3.79
# 3                                     Wii Sports Resort      3.28
# 4                              Pokemon Red/Pokemon Blue     10.22
# ...                                                 ...       ...
# 16593                Woody Woodpecker in Crazy Castle 5      0.00
# 16594                     Men in Black II: Alien Escape      0.00
# 16595  SCORE International Baja 1000: The Official Game      0.00
# 16596                                        Know How 2      0.00
# 16597                                  Spirits & Spells      0.00
#
# [16598 rows x 2 columns]

# %%
tabela[['Name', 'JP_Sales']].sort_values(by='JP_Sales', ascending = False).head(15)
# Out:
#                                                Name  JP_Sales
# 4                          Pokemon Red/Pokemon Blue     10.22
# 12                      Pokemon Gold/Pokemon Silver      7.20
# 1                                 Super Mario Bros.      6.81
# 6                             New Super Mario Bros.      6.50
# 20                    Pokemon Diamond/Pokemon Pearl      6.04
# 26                      Pokemon Black/Pokemon White      5.65
# 25                    Pokemon Ruby/Pokemon Sapphire      5.38
# 41                      Animal Crossing: Wild World      5.33
# 27      Brain Age 2: More Training in Minutes a Day      5.32
# 214                        Monster Hunter Freedom 3      4.87
# 8                         New Super Mario Bros. Wii      4.70
# 73                        Animal Crossing: New Leaf      4.36
# 149  Dragon Quest IX: Sentinels of the Starry Skies      4.35
# 32                              Pokemon X/Pokemon Y      4.34
# ...

# %% [markdown]
# ### Os japoneses gostam muito de jogar Pokemon!

# %%
tabela['JP_Sales'].max()
# Out:
# 10.22

# %% [markdown]
# # Os jogos mais vendidos por ano (variável Global_Sales)

# %%
tabela[['Year', 'Global_Sales']].head()
# Out:
#      Year  Global_Sales
# 0  2006.0         82.74
# 1  1985.0         40.24
# 2  2008.0         35.82
# 3  2009.0         33.00
# 4  1996.0         31.37

# %%
pd.unique(tabela['Year'])
# Out:
# array([2006., 1985., 2008., 2009., 1996., 1989., 1984., 2005., 1999.,
#        2007., 2010., 2013., 2004., 1990., 1988., 2002., 2001., 2011.,
#        1998., 2015., 2012., 2014., 1992., 1997., 1993., 1994., 1982.,
#        2003., 1986., 2000.,   nan, 1995., 2016., 1991., 1981., 1987.,
#        1980., 1983., 2020., 2017.])

# %%
x = pd.DataFrame(tabela['Year'].value_counts().keys(), columns=['Ano'])
x['Vendas'] = tabela['Year'].value_counts().values
ordenado = x.sort_values(by=['Ano'], ascending=False)
ordenado.head()
# Out:
#        Ano  Vendas
# 38  2020.0       1
# 37  2017.0       3
# 17  2016.0     344
# 11  2015.0     614
# 12  2014.0     582

# %% [markdown]
# Para plotar o gráfico de jogos mais vendidos por ano, é necessário programação.
#
# Algoritmo:
#
# 1 <-- Ordenar a variável 'Year'
#
# 2 <-- Criar duas listas para armazenar as observações das variáveis
#
# 3 <-- Fazer um laço de repetição, dentro do laço de repetição põe uma estrutura condicional onde fará o somatório das vendas de cada ano, por meio da coluna(variável) ordenada.

# %%
lista_anos = []
lista_vendas = []

for i in ordenado['Ano']:
    y = tabela[['Year', 'Global_Sales']].query("Year == %f" % i)
    y = np.sum(y['Global_Sales'])
    lista_anos.append(i)
    lista_vendas.append(y)

vendidos_por_ano = pd.DataFrame(lista_anos, columns=['Ano'])
vendidos_por_ano['Vendas'] = lista_vendas
vendidos_por_ano
# Out:
#        Ano  Vendas
# 0   2020.0    0.29
# 1   2017.0    0.05
# 2   2016.0   70.93
# 3   2015.0  264.44
# 4   2014.0  337.05
# 5   2013.0  368.11
# 6   2012.0  363.54
# 7   2011.0  515.99
# 8   2010.0  600.45
# 9   2009.0  667.30
# 10  2008.0  678.90
# 11  2007.0  611.13
# 12  2006.0  521.04
# 13  2005.0  459.94
# 14  2004.0  419.31
# 15  2003.0  357.85
# 16  2002.0  395.52
# 17  2001.0  331.47
# 18  2000.0  201.56
# 19  1999.0  251.27
# 20  1998.0  256.47
# 21  1997.0  200.98
# 22  1996.0  199.15
# 23  1995.0   88.11
# 24  1994.0   79.17
# 25  1993.0   45.98
# 26  1992.0   76.16
# 27  1991.0   32.23
# 28  1990.0   49.39
# 29  1989.0   73.45
# 30  1988.0   47.22
# 31  1987.0   21.74
# 32  1986.0   37.07
# 33  1985.0   53.94
# 34  1984.0   50.36
# 35  1983.0   16.79
# 36  1982.0   28.86
# 37  1981.0   35.77
# 38  1980.0   11.38

# %%
plt.bar(vendidos_por_ano['Ano'], vendidos_por_ano['Vendas'])
plt.title("Vendas de jogos por ano\n", fontsize=20)
plt.xlabel("\nAnos", fontsize=12)
plt.ylabel("Número de vendas\n", fontsize=12)
plt.show()

# %% [markdown]
# O ano de 2006 a 2010 foram anos que tiveram maiores vendas de jogos. Sendo que 2008 foi o ano que mais vendeu.

# %%
ordenado['Vendas'].max()
# Out:
# 1431

# %%
vendidos_por_ano.sort_values(by='Vendas', ascending=False)
# Out:
#        Ano  Vendas
# 10  2008.0  678.90
# 9   2009.0  667.30
# 11  2007.0  611.13
# 8   2010.0  600.45
# 12  2006.0  521.04
# 7   2011.0  515.99
# 13  2005.0  459.94
# 14  2004.0  419.31
# 16  2002.0  395.52
# 5   2013.0  368.11
# 6   2012.0  363.54
# 15  2003.0  357.85
# 4   2014.0  337.05
# 17  2001.0  331.47
# 3   2015.0  264.44
# 20  1998.0  256.47
# 19  1999.0  251.27
# 18  2000.0  201.56
# 21  1997.0  200.98
# 22  1996.0  199.15
# 23  1995.0   88.11
# 24  1994.0   79.17
# 26  1992.0   76.16
# 29  1989.0   73.45
# 2   2016.0   70.93
# 33  1985.0   53.94
# 34  1984.0   50.36
# 28  1990.0   49.39
# 30  1988.0   47.22
# 25  1993.0   45.98
# 32  1986.0   37.07
# 37  1981.0   35.77
# 27  1991.0   32.23
# 36  1982.0   28.86
# 31  1987.0   21.74
# 35  1983.0   16.79
# 38  1980.0   11.38
# 0   2020.0    0.29
# 1   2017.0    0.05

# %% [markdown]
# ### Os jogos mais vendidos de 2006

# %%
x = ordenado.query('Ano == 2006.0')
print(x)
# Out:
#       Ano  Vendas
# 5  2006.0    1008

# %%
x = tabela[['Name', 'Year', 'Global_Sales']]
x = x.query('Year == 2006.0').sort_values(by='Global_Sales', ascending=False)

# %%
plt.figure(figsize=(16, 12))
plt.bar(x['Name'].head(20), x['Global_Sales'].head(20))
plt.xticks(rotation=65.0)
plt.show()

# %% [markdown]
# A partir do gráfico posso tirar algumas conclusões sobre as vendas de jogos no ano de 2006. Guitar Hero 3 teve um número de vendas inferior a 10 e ficou no 9° jogo mais vendido de 2006

# %% [markdown]
# # Total de vendas da variável Global_Sales

# %%
np.sum(tabela['Global_Sales'])
# Out:
# 8920.44

# %%
np.sum(tabela[['Year', 'Global_Sales']].query("Year == 2006"))
# Out:
# Year            2022048.00
# Global_Sales        521.04
# dtype: float64

# %% [markdown]
# # Quais foram as desenvolvedoras que mais publicaram jogos?

# %%
ordenado['Ano'][3:19]
# Out:
# 11    2015.0
# 12    2014.0
# 13    2013.0
# 10    2012.0
# 4     2011.0
# 2     2010.0
# 0     2009.0
# 1     2008.0
# 3     2007.0
# 5     2006.0
# 6     2005.0
# 9     2004.0
# 8     2003.0
# 7     2002.0
# 14    2001.0
# 16    2000.0
# Name: Ano, dtype: float64

# %%
desenvolvedoras_jogos = pd.DataFrame(tabela['Publisher'].value_counts().keys(), columns=['Desenvolvedoras'])
desenvolvedoras_jogos['quant_Publisher'] = tabela['Publisher'].value_counts().values
desenvolvedoras_jogos.head(20)
# Out:
#                            Desenvolvedoras  quant_Publisher
# 0                          Electronic Arts             1351
# 1                               Activision              975
# 2                       Namco Bandai Games              932
# 3                                  Ubisoft              921
# 4             Konami Digital Entertainment              832
# 5                                      THQ              715
# 6                                 Nintendo              703
# 7              Sony Computer Entertainment              683
# 8                                     Sega              639
# 9                     Take-Two Interactive              413
# 10                                  Capcom              381
# 11                                   Atari              363
# 12                              Tecmo Koei              338
# 13                             Square Enix              233
# 14  Warner Bros. Interactive Entertainment              232
# ...

# %% [markdown]
# As vintes desenvolvedoras que mais desenvolveram games ao longo de 1980 a 2020

# %%
table = desenvolvedoras_jogos.sort_values(by=['quant_Publisher'], ascending=False).head(20)

plt.figure(figsize=(16, 12))
plt.plot(table['Desenvolvedoras'], table['quant_Publisher'])
plt.xticks(rotation=60)
plt.ylabel("Quantidade de jogos publicados\n", fontsize=20)
plt.xlabel("\nDesenvolvedoras", fontsize=20)
plt.grid(True)

# %% [markdown]
# # Quais foram as desenvolvedoras que mais publicaram jogos em 2006?

# %%
# tabela[['Year', 'Publisher']].query('Year == 2006').value_counts().keys()
table = pd.DataFrame( tabela[['Year', 'Publisher']].query('Year == 2006').value_counts().keys(), columns=['Desenvolvedoras'])
table['Quant_Publisher'] = tabela[['Year', 'Publisher']].query('Year == 2006').value_counts().values
table
# Out:
#                             Desenvolvedoras  Quant_Publisher
# 0                 (2006.0, Electronic Arts)              102
# 1              (2006.0, Namco Bandai Games)               66
# 2    (2006.0, Konami Digital Entertainment)               66
# 3                         (2006.0, Ubisoft)               61
# 4                             (2006.0, THQ)               57
# ..                                      ...              ...
# 107           (2006.0, Hamster Corporation)                1
# 108                  (2006.0, Groove Games)                1
# 109        (2006.0, Global A Entertainment)                1
# 110                    (2006.0, Ghostlight)                1
# 111               (2006.0, 10TACLE Studios)                1
#
# [112 rows x 2 columns]

# %%
table.sort_values(by='Quant_Publisher', ascending=False).head()
table['Quant_Publisher']
# Out:
# 0      102
# 1       66
# 2       66
# 3       61
# 4       57
#       ...
# 107      1
# 108      1
# 109      1
# 110      1
# 111      1
# Name: Quant_Publisher, Length: 112, dtype: int64

# %% [markdown]
# ### as 10 desenvolvedoras que mais publicaram jogos em 2006

# %%
plt.barh(table['Quant_Publisher'], table['Desenvolvedoras'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# <ipython-input-491-32223d8e5220> in <module>
# ----> 1 plt.barh(table['Quant_Publisher'], table['Desenvolvedoras'])
#       2 plt.show()
#
# F:\Programas\Anaconda\lib\site-packages\matplotlib\pyplot.py in barh(y, width, height, left, align, **kwargs)
#    2500 @_copy_docstring_and_deprecators(Axes.barh)
#    2501 def barh(y, width, height=0.8, left=None, *, align='center', **kwargs):
# -> 2502     return gca().barh(
#    2503         y, width, height=height, left=left, align=align, **kwargs)
#    2504
#
# F:\Programas\Anaconda\lib\site-packages\matplotlib\axes\_axes.py in barh(self, y, width, height, left, align, **kwargs)
#    2628         """
#    2629         kwargs.setdefault('orientation', 'horizontal')
# -> 2630         patches = self.bar(x=left, height=height, width=width, bottom=y,
# ...
